# %%
import os
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium import webdriver
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
import time
options_r = webdriver.ChromeOptions()
options_r.add_argument("--no-sandbox")
options_r.add_argument("--disable-dev-shm-usage")
browser = webdriver.Chrome(options=options_r)
browser.get("https://sirh.cdg22.fr/cgi-bin/acces.exe")
#frame = browser.find_element("xpath" , '//frame[@name="choixAppli"]')
#browser.switch_to.frame(frame)
original_window = browser.current_window_handle
name=browser.find_element("id","identifiant").send_keys("cirark")
password=browser.find_element("id","motPasse").send_keys("TestRPA611")
click_button=browser.find_element("id","inputSubmit").click()

navigateagnet=browser.find_element("xpath",'/html/body/div[2]/div[2]/div[2]/div/div/div[1]/div[2]/div').click()
all_window_handles=browser.window_handles
for window_handle in all_window_handles:
    if window_handle != original_window:
        browser.switch_to.window(window_handle)
        print('browser switched')
        break
agent_browser=browser.find_element("id",'E3TreeMenuSurvolLink')
print('element exist we click on it')
agent_browser=browser.find_element("xpath",'/html/body/div[28]/div[2]/div/div[1]/div[1]/div[1]/div[1]/ul/li[1]/div/span').click()
time.sleep(3)
matricule_path=browser.find_element('xpath' , '/html/body/div[37]/div[2]/div/div[2]/div[4]/div/div/div/div/div[2]/div/div[2]/div/div[2]/div[3]/div/div/div[2]/div/input').send_keys("34909")
recherche_button=browser.find_element('xpath' , '/html/body/div[37]/div[2]/div/div[2]/div[2]/div[2]/ul/li[1]/div/div/div[2]/div/div[3]/div/input').click()
time.sleep(2)
#button=browser.find_element('xpath' , '/html/body/div[37]/div[2]/div/div[1]/div[1]/div[1]/div[1]/ul/li[1]/div/div[1]').click()
time.sleep(4)
# Out:
# browser switched
# element exist we click on it

# %%
paie_button=browser.find_element('xpath','//div[2]/div/div[1]/div[1]/div[1]/div[1]/ul/li[6]/div/div[1]').click()

# %%
declaration_dsn=browser.find_element('xpath','//div[2]/div/div[1]/div[1]/div[1]/div[1]/ul/li[6]/ul/li[7]/div/div[1]').click()

# %%
gestion_envoie=browser.find_element('xpath','//div[2]/div/div[1]/div[1]/div[1]/div[1]/ul/li[6]/ul/li[7]/ul/li[2]').click()

# %%
from selenium.webdriver.common.action_chains import ActionChains

# %%
action = ActionChains(browser)
element=browser.find_element('xpath',"//div[2]/div/div[2]/div[4]/div/div/div/div/div[3]/div/div[1]/ul/li[1]/ul/li[2]/div/div[4]")

action.context_click(element).perform()

# %%
affecetr_un_nouvel_envoi=browser.find_element('xpath','/html/body/div[31]/div/div[1]/a').click()

# %%
valider_button=browser.find_element('xpath','/html/body/div[36]/div[2]/div[2]/div/div/div/div/div[2]/div/div[10]/div').click()

# %%
cocher=browser.find_element('xpath','/html/body/div[30]/div[2]/div/div[2]/div[5]/div/div/div/div/div[3]/div/div[3]/div/label/input').click()

# %%
declaration_evenementielle=browser.find_element('xpath','//div[2]/div/div[2]/div[4]/div/div/div/div/div[3]/div/div[1]/ul/li[2]/ul/li[2]/ul/li[2]')

# %%
action = ActionChains(browser)
element=browser.find_element('xpath',"//div[2]/div/div[2]/div[4]/div/div/div/div/div[3]/div/div[1]/ul/li[1]/ul/li[2]/div/div[4]")

action.context_click(declaration_evenementielle).perform()

# %%
gerer_envoie=browser.find_element('xpath' ,'/html/body/div[30]/div/div[3]').click()

# %%
Fichier_reel=browser.find_element('xpath','/html/body/div[40]/div[2]/div/div[2]/div[4]/div/div/div/div/div[13]/div/div/div/div/div[2]/div/div[4]/div/div[2]/div[5]/div/div[3]/div/div/div/input').clear()

# %%
Fichier_reel=browser.find_element('xpath','/html/body/div[40]/div[2]/div/div[2]/div[4]/div/div/div/div/div[13]/div/div/div/div/div[2]/div/div[4]/div/div[2]/div[5]/div/div[3]/div/div/div/input').send_keys('réel')

# %%
liste_systeme=browser.find_element('xpath','/html/body/div[39]/div[2]/div/div[2]/div[2]/div[2]/ul/li[14]/div/div/div[2]/div/div[3]/div/input').click()

# %%
browser.get("https://portail.net-entreprises.fr/auth/")
original_window = browser.current_window_handle

# %%
siret=browser.find_element('xpath','/html/body/div/main/form/div[1]/div/div[2]/div[1]/input').send_keys('28220110200039')

# %%
nom=browser.find_element('xpath','/html/body/div/main/form/div[1]/div/div[2]/div[2]/input').send_keys('CIRARK')

# %%
prenom=browser.find_element('xpath','/html/body/div/main/form/div[1]/div/div[2]/div[3]/input').send_keys('CIRARK')

# %%
mot_de_passe=browser.find_element('xpath','/html/body/div/main/form/div[1]/div/div[2]/div[4]/input').send_keys('QQVnp1x0*8mV')

# %%
authentification_button=browser.find_element('xpath','/html/body/div/main/form/div[1]/div/button').click()

# %%
dsn_regime_general=browser.find_element('xpath','/html/body/div[1]/main/div/div[2]/div/div/div/div[1]').click()

# %%
signalement_evenement=browser.find_element('xpath','/html/body/table/tbody/tr[3]/td[2]/div[9]/div[1]/input[2]').click()

# %%
file_input = browser.find_element("name", "depot")  # Ou find_element(By.NAME, "depot")

# Envoyer le fichier
file_path = r"C:\Users\Ghofrane\Downloads\Export test gestion absences_09072024.xlsx"  # Remplacez par votre chemin de fichier
file_input.send_keys(file_path)
